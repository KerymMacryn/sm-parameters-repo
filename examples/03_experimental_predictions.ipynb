# %% [markdown]
# # TSQVT: Experimental Predictions

# %%
from tsqvt.experimental import CollapsePredictor
predictor = CollapsePredictor(1e-14, 100e-9)
tau = predictor.compute_collapse_time()
print(f'τ = {tau*1000:.1f} ms')
