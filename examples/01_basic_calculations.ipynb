# %% [markdown]
# # TSQVT: Basic Calculations

# %%
import numpy as np
import tsqvt
print(f'TSQVT v{tsqvt.__version__}')

# %% [markdown]
# ## Spectral Manifold

# %%
from tsqvt.core import SpectralManifold
manifold = SpectralManifold()
print(manifold)
